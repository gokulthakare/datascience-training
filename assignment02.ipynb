# %% [markdown]
# <a href="https://colab.research.google.com/github/gokulthakare/datascience-training/blob/main/assignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

#upload csv file on drive
uploaded = files.upload()

import pandas as pd

# uploaded 'cricket.csv'
df = pd.read_csv('cricket.csv')

print(df.head())
# Out:
#      <input type="file" id="files-87a981d8-1796-4314-8162-e73c7e24a0d1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-87a981d8-1796-4314-8162-e73c7e24a0d1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#list cricketer name and respective runs
name_runs = df[['name', 'runs']]
print(name_runs)
# Out:
#             name  runs
# 0    Anil Dalpat  6755
# 1   Rohan Kanhay  1256
# 2  Avdhoot Dighe  8954
# 3       Bahubali   756
# 4      Leeladhar  2866
# 5      Pradyumna  5877
# 6     Dinesh Roy  8537
# 7     Parmeshwar  9466
# 8    Ali Durrani  2756
# 9   Litesh Singh  1099

# %%
wickets = df['wickets'].sum()
wickets
# Out:
# 790

# %%
catches= df['catches'].mean()
catches
# Out:
# 63.3

# %%
wkt_keeper = df[df['stumpings'] > 0]
name_wkt = wkt_keeper['name']

print(name_wkt)
# Out:
# 3    Bahubali
# Name: name, dtype: object

# %%
max_matches = df['matches'].max()
player_withmax_matches = df[df['matches'] == max_matches]['name'].iloc[0]
player_withmax_matches
# Out:
# 'Avdhoot Dighe'

# %%
df['avg_wickets_Match'] = df['wickets'] / df['matches']

# show columns
result = df[['name', 'avg_wickets_Match']]
result
# Out:
#             name  avg_wickets_Match
# 0    Anil Dalpat           0.098361
# 1   Rohan Kanhay           1.236111
# 2  Avdhoot Dighe           0.000000
# 3       Bahubali           1.100000
# 4      Leeladhar           1.606838
# 5      Pradyumna           0.689266
# 6     Dinesh Roy           0.075829
# 7     Parmeshwar           0.000000
# 8    Ali Durrani           0.472727
# 9   Litesh Singh           0.550562

# %%
result.max()
# Out:
# name                 Rohan Kanhay
# avg_wickets_Match        1.606838
# dtype: object

# %%
# 8 Least bowling avg
result.min()
# Out:
# name                 Ali Durrani
# avg_wickets_Match            0.0
# dtype: object

# %%
#9
df['catchpermatch'] = df['catches'] / df['matches']
player_catches = df[df['catchpermatch'] >= 0.5]['name']
player_catches
# Out:
# 1    Rohan Kanhay
# 3        Bahubali
# 6      Dinesh Roy
# 9    Litesh Singh
# Name: name, dtype: object

# %%
df.to_csv("player-inf", index=False)

# %%
#10 name againtst runs
import matplotlib.pyplot as plt

name_runs = df[['name', 'runs']]
#print(name_runs)
# Plotting
plt.figure(figsize=(10, 4))
plt.bar(name_runs['name'], name_runs['runs'], color='skyblue')
plt.xlabel('Name')
plt.ylabel('Runs')
plt.title('Runs by Player')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust layout to fit labels

# Show the plot
plt.show()

# %%
#11
sorted_ascending = df.sort_values(by='runs')
sorted_ascending
# Out:
#    sr.no           name  matches  runs  catches  wickets  stumpings  \
# 3      4       Bahubali       10   756        6       11          3
# 9     10   Litesh Singh       89  1099       46       49          0
# 1      2   Rohan Kanhay      144  1256       76      178          0
# 8      9    Ali Durrani       55  2756       12       26          0
# 4      5      Leeladhar      234  2866      105      376          0
# 5      6      Pradyumna      177  5877       47      122          0
# 0      1    Anil Dalpat      122  6755       56       12          0
# 6      7     Dinesh Roy      211  8537      112       16          0
# 2      3  Avdhoot Dighe      265  8954      120        0          0
# 7      8     Parmeshwar      245  9466       53        0          0
#
#    avg_wickets_Match  catchpermatch
# 3           1.100000       0.600000
# 9           0.550562       0.516854
# 1           1.236111       0.527778
# 8           0.472727       0.218182
# ...

# %%
#12
names_df = df[df['wickets'] > df['matches']]
names_df
# Out:
#    sr.no          name  matches  runs  catches  wickets  stumpings  \
# 1      2  Rohan Kanhay      144  1256       76      178          0
# 3      4      Bahubali       10   756        6       11          3
# 4      5     Leeladhar      234  2866      105      376          0
#
#    avg_wickets_Match  catchpermatch
# 1           1.236111       0.527778
# 3           1.100000       0.600000
# 4           1.606838       0.448718
